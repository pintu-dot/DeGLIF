# %%
'''Run this cell to install required packages'''

import os
if 'IS_GRADESCOPE_ENV' not in os.environ:
    # !pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2 --index-url https://download.pytorch.org/whl/cu118
    # !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-2.2.2+cu118.html
    # !pip install torch-sparse -f https://pytorch-geometric.com/whl/torch-2.2.2+cu118.html
    # !pip install torch-geometric==2.5.2
    # !pip install ogb
    # !pip install numpy==1.26.3
    # !pip install networkx==3.1
    # !pip install scikit-learn==1.2.2
    # !pip install matplotlib

# %%
'''Run this cell to verify installation of neccesary packages'''

import os
import torch
import networkx as nx
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import torch_geometric
import random
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures

import torch.nn.functional as F
device = 'cuda' if torch.cuda.is_available() else 'cpu'

from torch_geometric.nn import GCNConv
from torch_geometric.nn import SGConv
from sklearn.metrics import f1_score
import numpy as np
