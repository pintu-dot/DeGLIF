# %%
import numpy as np
from scipy.stats import wilcoxon

# ==========================================
# SYMMETRIC LABEL NOISE DATA
# ==========================================

# Cora (5%, 10%, 15%, 20%, 25%, 30%, 35%, 40%, 45%, 50%)
tss_sym_cora = [82.4, 82.4, 83.4, 81.9, 81.1, 80.3, 76.9, 78.4, 75.1, 74.5]
mv_sym_cora  = [85.1, 84.7, 84.0, 83.2, 82.7, 82.1, 82.0, 80.9, 79.0, 76.8]
sum_sym_cora = [86.1, 84.7, 85.8, 84.3, 84.6, 84.3, 84.8, 84.0, 81.1, 80.5]

# Citeseer
tss_sym_cite = [77.5, 76.9, 76.6, 77.5, 75.5, 74.1, 75.4, 73.0, 71.4, 70.3]
mv_sym_cite  = [77.8, 77.2, 76.9, 76.5, 76.5, 76.1, 75.4, 74.1, 74.2, 72.3]
sum_sym_cite = [81.5, 81.2, 80.7, 79.5, 79.7, 78.8, 77.4, 75.6, 76.3, 74.3]

# Amazon Photo
tss_sym_amz = [86.9, 85.3, 84.7, 86.8, 85.9, 86.3, 85.3, 83.6, 82.5, 78.9]
mv_sym_amz  = [89.6, 89.6, 89.9, 89.7, 88.9, 89.1, 88.6, 86.7, 83.5, 82.0]
sum_sym_amz = [91.8, 91.6, 90.8, 90.3, 90.0, 89.8, 88.1, 87.1, 86.4, 82.6]


# ==========================================
# PAIRWISE NOISE DATA
# ==========================================

# Cora
tss_pw_cora = [82.5, 81.6, 81.6, 80.6, 78.3, 74.8, 69.0, 63.6, 52.4, 45.0]
mv_pw_cora  = [86.3, 86.0, 84.8, 83.2, 81.1, 76.7, 72.1, 64.8, 57.9, 48.6]
sum_pw_cora = [86.5, 85.9, 84.1, 82.6, 80.8, 78.5, 73.9, 66.8, 63.0, 51.8]

# Citeseer
tss_pw_cite = [77.7, 77.8, 77.6, 75.9, 76.3, 75.4, 70.1, 64.5, 60.9, 46.1]
mv_pw_cite  = [79.8, 79.1, 78.4, 77.5, 76.7, 75.0, 71.6, 66.6, 51.5, 49.0]
sum_pw_cite = [80.2, 78.8, 78.2, 78.0, 77.8, 75.6, 73.4, 69.6, 63.7, 54.0]

# Amazon Photo
tss_pw_amz = [85.9, 83.6, 85.6, 85.9, 82.8, 80.6, 68.7, 67.1, 50.0, 39.4]
mv_pw_amz  = [87.5, 87.8, 89.8, 88.6, 82.8, 80.3, 73.1, 64.0, 66.1, 54.2]
sum_pw_amz = [89.6, 89.2, 89.2, 87.4, 85.3, 83.2, 77.0, 74.5, 71.8, 60.6]



# Concatenate all lists to form the 60-item arrays
tss_all = np.array(
    tss_sym_cora + tss_sym_cite + tss_sym_amz + 
    tss_pw_cora + tss_pw_cite + tss_pw_amz
)

sum_all = np.array(
    sum_sym_cora + sum_sym_cite + sum_sym_amz + 
    sum_pw_cora + sum_pw_cite + sum_pw_amz
)

mv_all = np.array(
    mv_sym_cora + mv_sym_cite + mv_sym_amz + 
    mv_pw_cora + mv_pw_cite + mv_pw_amz
)

# ==========================================
# PERFORM WILCOXON TESTS
# ==========================================

print("=== Wilcoxon Signed-Rank Test Results ===")

# Test 1: DeGLIF (sum) vs TSS
diff_sum = sum_all - tss_all
stat_sum, p_sum = wilcoxon(diff_sum, alternative='greater')
print("\nDeGLIF (sum) vs. TSS:")
print(f"Statistic: {stat_sum}")
print(f"P-value:   {p_sum:.4e}")
if p_sum < 0.05:
    print("Conclusion: DeGLIF (sum) is statistically significantly better than TSS.")
else:
    print("Conclusion: No statistically significant difference.")

# Test 2: DeGLIF (mv) vs TSS
diff_mv = mv_all - tss_all
stat_mv, p_mv = wilcoxon(diff_mv, alternative='greater')
print("\nDeGLIF (mv) vs. TSS:")
print(f"Statistic: {stat_mv}")
print(f"P-value:   {p_mv:.4e}")
if p_mv < 0.05:
    print("Conclusion: DeGLIF (mv) is statistically significantly better than TSS.")
else:
    print("Conclusion: No statistically significant difference.")
# Out:
# === Wilcoxon Signed-Rank Test Results ===
#
# DeGLIF (sum) vs. TSS:
# Statistic: 1830.0
# P-value:   8.0942e-12
# Conclusion: DeGLIF (sum) is statistically significantly better than TSS.
#
# DeGLIF (mv) vs. TSS:
# Statistic: 1597.5
# P-value:   4.5851e-09
# Conclusion: DeGLIF (mv) is statistically significantly better than TSS.

# %%
import numpy as np
import pandas as pd
from scipy.stats import wilcoxon


data = {
    "GCN": [
        85.5, 84.5, 83.1, 81.5, 79.2, 76.5, 72.8, 69.2, 65.1, 59.1,
        76.6, 73.9, 71.2, 69.0, 66.3, 63.4, 59.3, 55.4, 51.3, 48.0,
        87.3, 87.1, 85.5, 85.7, 85.7, 84.6, 83.7, 80.7, 79.1, 75.2,
        86.1, 85.2, 83.0, 80.0, 77.1, 72.7, 67.2, 60.4, 52.8, 43.7,
        78.6, 78.2, 76.8, 75.5, 73.2, 70.6, 67.0, 62.1, 47.1, 45.3,
        89.5, 88.6, 87.0, 83.5, 82.4, 77.6, 69.0, 60.8, 62.4, 50.9
    ],
    "Coteaching+": [
        81.5, 81.2, 79.9, 79.6, 79.4, 78.8, 77.7, 76.4, 74.2, 70.7,
        79.3, 77.8, 75.8, 73.6, 69.0, 71.8, 72.5, 65.6, 67.5, 61.7,
        84.4, 82.2, 82.0, 80.4, 73.2, 73.7, 61.1, 59.2, 57.1, 47.9,
        78.6, 78.6, 77.8, 78.3, 75.2, 74.9, 72.4, 65.8, 56.6, 40.6,
        74.9, 75.7, 72.7, 71.0, 67.0, 65.1, 63.0, 57.8, 51.8, 45.4,
        86.3, 88.6, 82.6, 84.1, 80.0, 78.9, 70.4, 72.9, 61.5, 53.9
    ],
    "NRGNN": [
        84.1, 83.9, 82.7, 82.0, 81.0, 79.8, 78.7, 76.5, 75.1, 72.5,
        75.2, 74.3, 73.3, 72.2, 71.8, 71.4, 70.4, 69.5, 68.7, 67.9,
        69.0, 68.1, 72.4, 66.5, 55.1, 60.0, 58.3, 60.0, 54.5, 51.5,
        85.3, 84.6, 84.1, 82.0, 80.6, 78.3, 72.3, 69.1, 62.3, 46.6,
        77.3, 76.1, 75.6, 73.0, 71.4, 68.6, 63.7, 57.6, 55.0, 45.4,
        65.3, 65.6, 67.3, 67.3, 60.8, 64.7, 61.8, 52.6, 52.2, 47.3
    ],
    "RTGNN": [
        79.2, 79.0, 80.7, 80.2, 83.8, 83.0, 82.5, 81.7, 84.0, 77.6,
        76.8, 76.5, 76.7, 76.4, 76.0, 76.3, 74.1, 73.2, 72.7, 72.7,
        80.8, 82.2, 83.6, 84.0, 82.9, 78.8, 79.3, 83.5, 86.0, 79.9,
        79.2, 80.5, 80.4, 82.0, 77.5, 74.3, 72.1, 59.6, 51.1, 43.6,
        76.7, 77.3, 76.0, 75.8, 74.3, 71.3, 71.0, 67.9, 57.6, 45.8,
        88.4, 86.6, 88.3, 87.1, 85.2, 77.6, 73.3, 75.2, 64.6, 44.0
    ],
    "CP": [
        82.9, 81.4, 82.9, 79.0, 80.3, 75.8, 77.7, 70.1, 70.0, 65.6,
        77.6, 72.9, 76.6, 74.5, 71.2, 69.9, 65.5, 69.1, 67.0, 63.4,
        91.4, 90.6, 90.4, 89.9, 90.2, 89.9, 88.9, 87.3, 85.6, 83.0,
        82.2, 81.9, 78.5, 74.8, 71.0, 66.4, 56.4, 56.1, 48.9, 37.3,
        78.3, 73.9, 65.7, 66.2, 64.3, 59.4, 54.9, 49.4, 43.5, 41.1,
        90.7, 91.3, 89.4, 88.8, 86.4, 80.8, 77.9, 68.9, 59.6, 49.4
    ],
    "CGNN": [
        83.4, 83.1, 82.5, 82.2, 82.9, 83.2, 81.2, 78.6, 77.0, 73.0,
        75.6, 73.9, 71.5, 71.4, 75.6, 71.6, 69.3, 68.8, 59.8, 64.3,
        61.1, 66.4, 51.4, 69.6, 61.7, 54.2, 52.0, 43.0, 42.3, 40.3,
        84.1, 83.6, 82.4, 79.3, 78.4, 74.5, 69.0, 58.2, 53.0, 47.0,
        75.0, 77.0, 75.3, 69.3, 69.1, 65.8, 61.5, 55.1, 44.5, 42.8,
        64.4, 61.5, 68.1, 58.2, 48.3, 49.3, 46.1, 41.4, 40.1, 30.3
    ],
    "CRGNN": [
        84.5, 84.6, 82.8, 80.7, 80.3, 78.5, 73.8, 67.6, 66.6, 54.4,
        76.3, 74.8, 72.7, 73.2, 73.2, 66.6, 70.3, 67.0, 64.8, 58.6,
        37.5, 20.7, 33.5, 19.2, 37.5, 30.8, 32.2, 24.4, 50.9, 12.3,
        84.6, 80.6, 78.0, 75.4, 58.9, 69.9, 60.7, 47.3, 47.3, 42.8,
        75.1, 72.9, 68.5, 67.6, 66.0, 58.3, 55.1, 52.0, 45.2, 39.2,
        34.9, 21.3, 21.3, 36.0, 20.3, 42.7, 18.2, 15.4, 25.3, 11.1
    ],
    "RNCGLN": [
        83.0, 79.8, 78.1, 76.7, 73.6, 70.4, 67.0, 62.6, 54.2, 51.7,
        72.2, 69.4, 67.7, 66.1, 65.1, 63.8, 58.3, 57.8, 51.7, 47.4,
        85.9, 84.7, 80.2, 82.7, 72.8, 74.1, 70.9, 64.2, 62.2, 46.6,
        79.4, 78.6, 75.8, 71.1, 65.7, 63.0, 56.2, 51.5, 45.7, 40.0,
        69.9, 68.3, 66.1, 62.4, 58.2, 55.8, 53.6, 47.6, 41.9, 37.9,
        86.3, 84.6, 82.4, 80.7, 77.7, 71.2, 67.3, 55.7, 50.9, 43.3
    ],
    "PIGNN": [
        81.9, 83.3, 84.0, 81.2, 81.9, 78.8, 82.2, 78.0, 71.1, 75.9,
        76.6, 73.2, 72.3, 70.8, 71.6, 71.0, 66.6, 67.4, 60.8, 60.5,
        88.9, 90.1, 91.0, 88.1, 86.8, 87.6, 86.3, 82.5, 82.2, 76.9,
        83.9, 82.1, 83.1, 78.8, 76.8, 72.8, 71.0, 54.1, 58.3, 40.7,
        74.0, 72.9, 71.1, 68.8, 66.2, 62.7, 57.7, 51.3, 44.5, 40.7,
        89.4, 89.8, 88.1, 86.4, 81.8, 80.1, 76.8, 65.7, 62.5, 49.9
    ],
    "DGNN": [
        80.8, 79.0, 80.9, 67.9, 77.3, 73.2, 64.3, 61.9, 65.0, 60.0,
        66.5, 62.1, 59.9, 56.1, 53.1, 46.9, 46.5, 38.7, 41.9, 33.3,
        64.9, 65.3, 55.7, 54.4, 56.1, 57.2, 53.0, 48.1, 46.6, 44.1,
        82.9, 79.4, 75.4, 74.3, 65.3, 65.5, 58.9, 56.0, 49.1, 44.5,
        64.0, 60.9, 56.6, 52.8, 49.8, 49.3, 40.6, 36.8, 32.6, 29.6,
        67.4, 63.7, 62.7, 60.0, 54.7, 50.4, 49.2, 48.5, 43.9, 34.6
    ],
    "TSS": [
        82.4, 82.4, 83.4, 81.9, 81.1, 80.3, 76.9, 78.4, 75.1, 74.5,
        77.5, 76.9, 76.6, 77.5, 75.5, 74.1, 75.4, 73.0, 71.4, 70.3,
        86.9, 85.3, 84.7, 86.8, 85.9, 86.3, 85.3, 83.6, 82.5, 78.9,
        82.5, 81.6, 81.6, 80.6, 78.3, 74.8, 69.0, 63.6, 52.4, 45.0,
        77.7, 77.8, 77.6, 75.9, 76.3, 75.4, 70.1, 64.5, 60.9, 46.1,
        85.9, 83.6, 85.6, 85.9, 82.8, 80.6, 68.7, 67.1, 50.0, 39.4
    ],
    "DeGLIF_mv": [
        85.1, 84.7, 84.0, 83.2, 82.7, 82.1, 82.0, 80.9, 79.0, 76.8,
        77.8, 77.2, 76.9, 76.5, 76.5, 76.1, 75.4, 74.1, 74.2, 72.3,
        89.6, 89.6, 89.9, 89.7, 88.9, 89.1, 88.6, 86.7, 83.5, 82.0,
        86.3, 86.0, 84.8, 83.2, 81.1, 76.7, 72.1, 64.8, 57.9, 48.6,
        79.8, 79.1, 78.4, 77.5, 76.7, 75.0, 71.6, 66.6, 51.5, 49.0,
        87.5, 87.8, 89.8, 88.6, 82.8, 80.3, 73.1, 64.0, 66.1, 54.2
    ]
}

df = pd.DataFrame(data)

# ==========================================
# COMPUTE AVERAGE RANKS
# ==========================================

ranks = df.rank(axis=1, method='min', ascending=False)

# Calculate the mean of these ranks across all 60 conditions
average_ranks = ranks.mean().sort_values()

print("=== Average Ranks (Lower is Better) ===")
print(average_ranks.to_string(float_format="%.2f"))
print("\n")

# ==========================================
# STATISTICAL COMPARISON (1st vs 2nd)
# ==========================================
best_method = average_ranks.index[0]
second_best_method = average_ranks.index[1]

print(f"Top Method:      {best_method} (Avg Rank: {average_ranks[best_method]:.2f})")
print(f"Second Best:     {second_best_method} (Avg Rank: {average_ranks[second_best_method]:.2f})")

best_acc = df[best_method]
second_best_acc = df[second_best_method]
differences = best_acc - second_best_acc

stat, p_value = wilcoxon(differences, alternative='greater')

print("\n=== Wilcoxon Signed-Rank Test ===")
print(f"Comparing: {best_method} vs {second_best_method}")
print(f"Statistic: {stat}")
print(f"P-value:   {p_value:.4e}")

if p_value < 0.05:
    print(f"Conclusion: {best_method} is statistically significantly better than {second_best_method} (p < 0.05).")
else:
    print(f"Conclusion: The difference between {best_method} and {second_best_method} is not statistically significant at the 0.05 level.")
# Out:
# === Average Ranks (Lower is Better) ===
# DeGLIF_mv      2.03
# RTGNN          4.30
# TSS            4.32
# PIGNN          5.68
# NRGNN          5.90
# CP             5.92
# GCN            5.93
# Coteaching+    6.43
# CGNN           7.27
# CRGNN          9.30
# RNCGLN         9.77
# DGNN          10.78
#
#
# Top Method:      DeGLIF_mv (Avg Rank: 2.03)
# Second Best:     RTGNN (Avg Rank: 4.30)
#
# === Wilcoxon Signed-Rank Test ===
# Comparing: DeGLIF_mv vs RTGNN
# Statistic: 1456.0
# P-value:   8.1485e-06
# Conclusion: DeGLIF_mv is statistically significantly better than RTGNN (p < 0.05).

# %%
best_acc = df['DeGLIF_mv']
second_best_acc = df['TSS']
differences = best_acc - second_best_acc
stat, p_value = wilcoxon(differences, alternative='greater')

print("\n=== Wilcoxon Signed-Rank Test ===")
print(f"Comparing: DeGLIF_mv vs TSS")
print(f"Statistic: {stat}")
print(f"P-value:   {p_value:.4e}")
# Out:
# === Wilcoxon Signed-Rank Test ===
# Comparing: DeGLIF_mv vs TSS
# Statistic: 1597.5
# P-value:   4.5851e-09

# %%
import numpy as np
import pandas as pd
from scipy.stats import wilcoxon




data = {
    "GCN": [
        85.5, 84.5, 83.1, 81.5, 79.2, 76.5, 72.8, 69.2, 65.1, 59.1,
        76.6, 73.9, 71.2, 69.0, 66.3, 63.4, 59.3, 55.4, 51.3, 48.0,
        87.3, 87.1, 85.5, 85.7, 85.7, 84.6, 83.7, 80.7, 79.1, 75.2,
        86.1, 85.2, 83.0, 80.0, 77.1, 72.7, 67.2, 60.4, 52.8, 43.7,
        78.6, 78.2, 76.8, 75.5, 73.2, 70.6, 67.0, 62.1, 47.1, 45.3,
        89.5, 88.6, 87.0, 83.5, 82.4, 77.6, 69.0, 60.8, 62.4, 50.9
    ],
    "Coteaching+": [
        81.5, 81.2, 79.9, 79.6, 79.4, 78.8, 77.7, 76.4, 74.2, 70.7,
        79.3, 77.8, 75.8, 73.6, 69.0, 71.8, 72.5, 65.6, 67.5, 61.7,
        84.4, 82.2, 82.0, 80.4, 73.2, 73.7, 61.1, 59.2, 57.1, 47.9,
        78.6, 78.6, 77.8, 78.3, 75.2, 74.9, 72.4, 65.8, 56.6, 40.6,
        74.9, 75.7, 72.7, 71.0, 67.0, 65.1, 63.0, 57.8, 51.8, 45.4,
        86.3, 88.6, 82.6, 84.1, 80.0, 78.9, 70.4, 72.9, 61.5, 53.9
    ],
    "NRGNN": [
        84.1, 83.9, 82.7, 82.0, 81.0, 79.8, 78.7, 76.5, 75.1, 72.5,
        75.2, 74.3, 73.3, 72.2, 71.8, 71.4, 70.4, 69.5, 68.7, 67.9,
        69.0, 68.1, 72.4, 66.5, 55.1, 60.0, 58.3, 60.0, 54.5, 51.5,
        85.3, 84.6, 84.1, 82.0, 80.6, 78.3, 72.3, 69.1, 62.3, 46.6,
        77.3, 76.1, 75.6, 73.0, 71.4, 68.6, 63.7, 57.6, 55.0, 45.4,
        65.3, 65.6, 67.3, 67.3, 60.8, 64.7, 61.8, 52.6, 52.2, 47.3
    ],
    "RTGNN": [
        79.2, 79.0, 80.7, 80.2, 83.8, 83.0, 82.5, 81.7, 84.0, 77.6,
        76.8, 76.5, 76.7, 76.4, 76.0, 76.3, 74.1, 73.2, 72.7, 72.7,
        80.8, 82.2, 83.6, 84.0, 82.9, 78.8, 79.3, 83.5, 86.0, 79.9,
        79.2, 80.5, 80.4, 82.0, 77.5, 74.3, 72.1, 59.6, 51.1, 43.6,
        76.7, 77.3, 76.0, 75.8, 74.3, 71.3, 71.0, 67.9, 57.6, 45.8,
        88.4, 86.6, 88.3, 87.1, 85.2, 77.6, 73.3, 75.2, 64.6, 44.0
    ],
    "CP": [
        82.9, 81.4, 82.9, 79.0, 80.3, 75.8, 77.7, 70.1, 70.0, 65.6,
        77.6, 72.9, 76.6, 74.5, 71.2, 69.9, 65.5, 69.1, 67.0, 63.4,
        91.4, 90.6, 90.4, 89.9, 90.2, 89.9, 88.9, 87.3, 85.6, 83.0,
        82.2, 81.9, 78.5, 74.8, 71.0, 66.4, 56.4, 56.1, 48.9, 37.3,
        78.3, 73.9, 65.7, 66.2, 64.3, 59.4, 54.9, 49.4, 43.5, 41.1,
        90.7, 91.3, 89.4, 88.8, 86.4, 80.8, 77.9, 68.9, 59.6, 49.4
    ],
    "CGNN": [
        83.4, 83.1, 82.5, 82.2, 82.9, 83.2, 81.2, 78.6, 77.0, 73.0,
        75.6, 73.9, 71.5, 71.4, 75.6, 71.6, 69.3, 68.8, 59.8, 64.3,
        61.1, 66.4, 51.4, 69.6, 61.7, 54.2, 52.0, 43.0, 42.3, 40.3,
        84.1, 83.6, 82.4, 79.3, 78.4, 74.5, 69.0, 58.2, 53.0, 47.0,
        75.0, 77.0, 75.3, 69.3, 69.1, 65.8, 61.5, 55.1, 44.5, 42.8,
        64.4, 61.5, 68.1, 58.2, 48.3, 49.3, 46.1, 41.4, 40.1, 30.3
    ],
    "CRGNN": [
        84.5, 84.6, 82.8, 80.7, 80.3, 78.5, 73.8, 67.6, 66.6, 54.4,
        76.3, 74.8, 72.7, 73.2, 73.2, 66.6, 70.3, 67.0, 64.8, 58.6,
        37.5, 20.7, 33.5, 19.2, 37.5, 30.8, 32.2, 24.4, 50.9, 12.3,
        84.6, 80.6, 78.0, 75.4, 58.9, 69.9, 60.7, 47.3, 47.3, 42.8,
        75.1, 72.9, 68.5, 67.6, 66.0, 58.3, 55.1, 52.0, 45.2, 39.2,
        34.9, 21.3, 21.3, 36.0, 20.3, 42.7, 18.2, 15.4, 25.3, 11.1
    ],
    "RNCGLN": [
        83.0, 79.8, 78.1, 76.7, 73.6, 70.4, 67.0, 62.6, 54.2, 51.7,
        72.2, 69.4, 67.7, 66.1, 65.1, 63.8, 58.3, 57.8, 51.7, 47.4,
        85.9, 84.7, 80.2, 82.7, 72.8, 74.1, 70.9, 64.2, 62.2, 46.6,
        79.4, 78.6, 75.8, 71.1, 65.7, 63.0, 56.2, 51.5, 45.7, 40.0,
        69.9, 68.3, 66.1, 62.4, 58.2, 55.8, 53.6, 47.6, 41.9, 37.9,
        86.3, 84.6, 82.4, 80.7, 77.7, 71.2, 67.3, 55.7, 50.9, 43.3
    ],
    "PIGNN": [
        81.9, 83.3, 84.0, 81.2, 81.9, 78.8, 82.2, 78.0, 71.1, 75.9,
        76.6, 73.2, 72.3, 70.8, 71.6, 71.0, 66.6, 67.4, 60.8, 60.5,
        88.9, 90.1, 91.0, 88.1, 86.8, 87.6, 86.3, 82.5, 82.2, 76.9,
        83.9, 82.1, 83.1, 78.8, 76.8, 72.8, 71.0, 54.1, 58.3, 40.7,
        74.0, 72.9, 71.1, 68.8, 66.2, 62.7, 57.7, 51.3, 44.5, 40.7,
        89.4, 89.8, 88.1, 86.4, 81.8, 80.1, 76.8, 65.7, 62.5, 49.9
    ],
    "DGNN": [
        80.8, 79.0, 80.9, 67.9, 77.3, 73.2, 64.3, 61.9, 65.0, 60.0,
        66.5, 62.1, 59.9, 56.1, 53.1, 46.9, 46.5, 38.7, 41.9, 33.3,
        64.9, 65.3, 55.7, 54.4, 56.1, 57.2, 53.0, 48.1, 46.6, 44.1,
        82.9, 79.4, 75.4, 74.3, 65.3, 65.5, 58.9, 56.0, 49.1, 44.5,
        64.0, 60.9, 56.6, 52.8, 49.8, 49.3, 40.6, 36.8, 32.6, 29.6,
        67.4, 63.7, 62.7, 60.0, 54.7, 50.4, 49.2, 48.5, 43.9, 34.6
    ],
    "TSS": [
        82.4, 82.4, 83.4, 81.9, 81.1, 80.3, 76.9, 78.4, 75.1, 74.5,
        77.5, 76.9, 76.6, 77.5, 75.5, 74.1, 75.4, 73.0, 71.4, 70.3,
        86.9, 85.3, 84.7, 86.8, 85.9, 86.3, 85.3, 83.6, 82.5, 78.9,
        82.5, 81.6, 81.6, 80.6, 78.3, 74.8, 69.0, 63.6, 52.4, 45.0,
        77.7, 77.8, 77.6, 75.9, 76.3, 75.4, 70.1, 64.5, 60.9, 46.1,
        85.9, 83.6, 85.6, 85.9, 82.8, 80.6, 68.7, 67.1, 50.0, 39.4
    ],
    "DeGLIF_sum": [
        86.1, 84.7, 85.8, 84.3, 84.6, 84.3, 84.8, 84.0, 81.1, 80.5,
        81.5, 81.2, 80.7, 79.5, 79.7, 78.8, 77.4, 75.6, 76.3, 74.3,
        91.8, 91.6, 90.8, 90.3, 90.0, 89.8, 88.1, 87.1, 86.4, 82.6,
        86.5, 85.9, 84.1, 82.6, 80.8, 78.5, 73.9, 66.8, 63.0, 51.8,
        80.2, 78.8, 78.2, 78.0, 77.8, 75.6, 73.4, 69.6, 63.7, 54.0,
        89.6, 89.2, 89.2, 87.4, 85.3, 83.2, 77.0, 74.5, 71.8, 60.6
    ]
}

df = pd.DataFrame(data)

# ==========================================
# COMPUTE AVERAGE RANKS
# ==========================================
ranks = df.rank(axis=1, method='min', ascending=False)

# Calculate the mean of these ranks across all 60 conditions
average_ranks = ranks.mean().sort_values()

print("=== Average Ranks (Lower is Better) ===")
print(average_ranks.to_string(float_format="%.2f"))
print("\n")

# ==========================================
# STATISTICAL COMPARISON (1st vs 2nd)
# ==========================================
best_method = average_ranks.index[0]
second_best_method = average_ranks.index[1]

print(f"Top Method:      {best_method} (Avg Rank: {average_ranks[best_method]:.2f})")
print(f"Second Best:     {second_best_method} (Avg Rank: {average_ranks[second_best_method]:.2f})")

best_acc = df[best_method]
second_best_acc = df[second_best_method]
differences = best_acc - second_best_acc

stat, p_value = wilcoxon(differences, alternative='greater')

print("\n=== Wilcoxon Signed-Rank Test ===")
print(f"Comparing: {best_method} vs {second_best_method}")
print(f"Statistic: {stat}")
print(f"P-value:   {p_value:.4e}")

if p_value < 0.05:
    print(f"Conclusion: {best_method} is statistically significantly better than {second_best_method} (p < 0.05).")
else:
    print(f"Conclusion: The difference between {best_method} and {second_best_method} is not statistically significant at the 0.05 level.")
# Out:
# === Average Ranks (Lower is Better) ===
# DeGLIF_sum     1.27
# TSS            4.43
# RTGNN          4.53
# PIGNN          5.80
# NRGNN          5.95
# GCN            5.98
# CP             6.02
# Coteaching+    6.55
# CGNN           7.30
# CRGNN          9.30
# RNCGLN         9.77
# DGNN          10.78
#
#
# Top Method:      DeGLIF_sum (Avg Rank: 1.27)
# Second Best:     TSS (Avg Rank: 4.43)
#
# === Wilcoxon Signed-Rank Test ===
# Comparing: DeGLIF_sum vs TSS
# Statistic: 1830.0
# P-value:   8.0942e-12
# Conclusion: DeGLIF_sum is statistically significantly better than TSS (p < 0.05).

# %%
best_acc = df['DeGLIF_sum']
second_best_acc = df['RTGNN']
differences = best_acc - second_best_acc
stat, p_value = wilcoxon(differences, alternative='greater')

print("\n=== Wilcoxon Signed-Rank Test ===")
print(f"Comparing: DeGLIF_sum vs RTGNN")
print(f"Statistic: {stat}")
print(f"P-value:   {p_value:.4e}")
# Out:
# === Wilcoxon Signed-Rank Test ===
# Comparing: DeGLIF_sum vs RTGNN
# Statistic: 1801.5
# P-value:   3.3716e-11
